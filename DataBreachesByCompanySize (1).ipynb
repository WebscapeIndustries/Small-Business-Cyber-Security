# %%
# Load Packages
import math
import numpy as np
import pandas as pd
import param
#import holoviews as hv
import matplotlib.pyplot as plt
import panel as pn 
from panel.interact import interact, interactive, fixed, interact_manual
from panel import widgets
pn.extension()
from math import pi
from bokeh.palettes import Category20c, Category20, Category10
from bokeh.plotting import figure
from bokeh.transform import cumsum
from bokeh.io import output_file, show, output_notebook, push_notebook
from bokeh.models import LabelSet, Legend, HoverTool, LegendItem
from bokeh.models.sources import ColumnDataSource
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
colors = ['#9ecae1','#6baed6','#4292c6','#2171b5']
explode = (.1,0,0,0)
mylabels = ["Less than 100 \n employees", "101 to 1,000 \n employees", 
            "1,001-10,000 \n employees","Over 10,000 \n employees"]

db = np.array([.250,.270,.250,.11+.04+.02+.06])

fig, ax = plt.subplots(1, 1 , figsize=(9.8,8.2)) # using the variable ax for a single Axes
ax.pie(db,explode=explode,labels = mylabels,colors=colors,
       labeldistance=1.2,textprops=dict({'size': 'x-large'} ,color='black'),
       autopct='%1.1f%%', shadow=True)

ax.set_title("Data Breaches by Company Size", fontsize = 30, loc='center',pad=30)
ax.text(0,-1.5,
        "BASED ON 1,279 COMPANY BREACHES BETWEEN 2017-2021",
       horizontalalignment="center",fontsize=12, color='#4c4e7e',
       fontweight='bold')
fig.savefig('data-breaches-by-company-size')
plt.show()
